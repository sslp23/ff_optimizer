# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'

import numpy as np
from tqdm import tqdm

# %%
df = pd.read_csv(f"processed data/wr_proc_data.csv")

# %%
df = df[df["Rookie"] == 0]

# %%
df[["pid", "Player", "FPTS/G_MISC_avg", "FPTS/G_MISC_ewm", "Season"]].sort_values("FPTS/G_MISC_avg", ascending=0)
# Out:
#        pid               Player  FPTS/G_MISC_avg  FPTS/G_MISC_ewm  Season
# 3     9808   Antonio Brown (FA)        18.400000        18.313937    2018
# 414  12123   Davante Adams (LV)        18.033333        18.468353    2021
# 265   9808   Antonio Brown (FA)        17.900000        18.010994    2019
# 561  12123   Davante Adams (LV)        17.833333        18.147194    2022
# 351   9808   Antonio Brown (FA)        16.933333        16.400943    2020
# ..     ...                  ...              ...              ...     ...
# 558  13977   Ty Montgomery (NE)         0.000000         0.000000    2021
# 409  13977   Ty Montgomery (NE)         0.000000         0.000000    2020
# 69   16757     David Moore (TB)         0.000000         0.000000    2018
# 536  19736  Dezmon Patmon (BUF)         0.000000         0.000000    2021
# 78   16388       John Ross (FA)        -0.300000        -0.300000    2018
#
# [542 rows x 5 columns]

# %%
df.Season.value_counts()
# Out:
# 2018    128
# 2021    123
# 2019    117
# 2020    101
# 2022     73
# Name: Season, dtype: int64

# %%
corrs = df.corr(numeric_only=True)

# %%
corrs[["FPTS_TG"]]
# Out:
#                         FPTS_TG
# pid                   -0.028053
# Season                 0.107320
# AVG                   -0.715617
# FPTS_TG                1.000000
# FPTS/G_MISC_avg        0.676110
# ATT_RUSHING/G_avg     -0.042159
# YDS_RUSHING/G_avg      0.017107
# TD_RUSHING/G_avg       0.023284
# REC_RECEIVING/G_avg    0.638836
# TGT_RECEIVING/G_avg    0.617874
# YDS_RECEIVING/G_avg    0.668811
# TD_RECEIVING/G_avg     0.569134
# FL_MISC/G_avg          0.085938
# YDS/ATT_RUSHING_avg    0.101775
# TD/ATT_RUSHING_avg     0.048859
# YDS/REC_RECEIVING_avg  0.113846
# YDS/TGT_RECEIVING_avg  0.269479
# REC/TGT_RECEIVING_avg  0.207290
# TD/TGT_RECEIVING_avg   0.061234
# FPTS/G_MISC_ewm        0.690826
# ATT_RUSHING/G_ewm     -0.040669
# YDS_RUSHING/G_ewm      0.015064
# TD_RUSHING/G_ewm       0.022950
# REC_RECEIVING/G_ewm    0.652924
# TGT_RECEIVING/G_ewm    0.634680
# YDS_RECEIVING/G_ewm    0.684087
# TD_RECEIVING/G_ewm     0.578765
# FL_MISC/G_ewm          0.080016
# YDS/ATT_RUSHING_ewm    0.096285
# TD/ATT_RUSHING_ewm     0.046049
# YDS/REC_RECEIVING_ewm  0.128444
# YDS/TGT_RECEIVING_ewm  0.277464
# REC/TGT_RECEIVING_ewm  0.195782
# TD/TGT_RECEIVING_ewm   0.053057
# Rookie                      NaN
# Career_Years           0.122574

# %%
rel_cols = ["Season"]
for i, vals in corrs[["FPTS_TG"]].iterrows():
    val = vals["FPTS_TG"]
    if (val > 0.11 or val < -0.11) and "_ls" not in i:
        rel_cols.append(i)

# %%
rel_df = df[rel_cols]

# %%
rel_cols
# Out:
# ['Season',
#  'AVG',
#  'FPTS_TG',
#  'FPTS/G_MISC_avg',
#  'REC_RECEIVING/G_avg',
#  'TGT_RECEIVING/G_avg',
#  'YDS_RECEIVING/G_avg',
#  'TD_RECEIVING/G_avg',
#  'YDS/REC_RECEIVING_avg',
#  'YDS/TGT_RECEIVING_avg',
#  'REC/TGT_RECEIVING_avg',
#  'FPTS/G_MISC_ewm',
#  'REC_RECEIVING/G_ewm',
#  'TGT_RECEIVING/G_ewm',
#  'YDS_RECEIVING/G_ewm',
#  'TD_RECEIVING/G_ewm',
#  'YDS/REC_RECEIVING_ewm',
#  'YDS/TGT_RECEIVING_ewm',
#  'REC/TGT_RECEIVING_ewm',
#  'Career_Years']

# %%
for col in rel_cols[2:]:
    if "FPTS_TG" not in col:
        new_c = rel_df[col]/rel_df["AVG"]

        new_name = col+"_ADP"
    
        rel_df[new_name] = new_c

# %%
corrs = rel_df.corr()

# %%
corrs[["FPTS_TG"]]
# Out:
#                             FPTS_TG
# Season                     0.107320
# AVG                       -0.715617
# FPTS_TG                    1.000000
# FPTS/G_MISC_avg            0.676110
# REC_RECEIVING/G_avg        0.638836
# TGT_RECEIVING/G_avg        0.617874
# YDS_RECEIVING/G_avg        0.668811
# TD_RECEIVING/G_avg         0.569134
# YDS/REC_RECEIVING_avg      0.113846
# YDS/TGT_RECEIVING_avg      0.269479
# REC/TGT_RECEIVING_avg      0.207290
# FPTS/G_MISC_ewm            0.690826
# REC_RECEIVING/G_ewm        0.652924
# TGT_RECEIVING/G_ewm        0.634680
# YDS_RECEIVING/G_ewm        0.684087
# TD_RECEIVING/G_ewm         0.578765
# YDS/REC_RECEIVING_ewm      0.128444
# YDS/TGT_RECEIVING_ewm      0.277464
# REC/TGT_RECEIVING_ewm      0.195782
# Career_Years               0.122574
# FPTS/G_MISC_avg_ADP        0.537256
# REC_RECEIVING/G_avg_ADP    0.525202
# TGT_RECEIVING/G_avg_ADP    0.537472
# YDS_RECEIVING/G_avg_ADP    0.536419
# TD_RECEIVING/G_avg_ADP     0.519710
# YDS/REC_RECEIVING_avg_ADP  0.579916
# YDS/TGT_RECEIVING_avg_ADP  0.572748
# REC/TGT_RECEIVING_avg_ADP  0.561545
# FPTS/G_MISC_ewm_ADP        0.533781
# REC_RECEIVING/G_ewm_ADP    0.522615
# TGT_RECEIVING/G_ewm_ADP    0.536346
# YDS_RECEIVING/G_ewm_ADP    0.533333
# TD_RECEIVING/G_ewm_ADP     0.515705
# YDS/REC_RECEIVING_ewm_ADP  0.579148
# YDS/TGT_RECEIVING_ewm_ADP  0.571064
# REC/TGT_RECEIVING_ewm_ADP  0.560269
# Career_Years_ADP           0.513598

# %%
model_cols = ["Season"]
for i, vals in corrs[["FPTS_TG"]].iterrows():
    val = vals["FPTS_TG"]
    if val > 0.55 or val < -0.55:
        model_cols.append(i)

# %%
model_cols
# Out:
# ['Season',
#  'AVG',
#  'FPTS_TG',
#  'FPTS/G_MISC_avg',
#  'REC_RECEIVING/G_avg',
#  'TGT_RECEIVING/G_avg',
#  'YDS_RECEIVING/G_avg',
#  'TD_RECEIVING/G_avg',
#  'FPTS/G_MISC_ewm',
#  'REC_RECEIVING/G_ewm',
#  'TGT_RECEIVING/G_ewm',
#  'YDS_RECEIVING/G_ewm',
#  'TD_RECEIVING/G_ewm',
#  'YDS/REC_RECEIVING_avg_ADP',
#  'YDS/TGT_RECEIVING_avg_ADP',
#  'REC/TGT_RECEIVING_avg_ADP',
#  'YDS/REC_RECEIVING_ewm_ADP',
#  'YDS/TGT_RECEIVING_ewm_ADP',
#  'REC/TGT_RECEIVING_ewm_ADP']

# %%
#rel_df = df[rel_cols]

# %%
for col in rel_df.columns[2:]:
    if "FPTS" not in col and "_ADP" not in col:
        if "_avg" in col:
            new_c = rel_df["FPTS/G_MISC_avg"]*rel_df[col]
        elif "_ewm" in col:
            new_c = rel_df["FPTS/G_MISC_ewm"]*rel_df[col]
        
        new_name = col+"_FP"

        rel_df[new_name] = new_c

# %%
corrs = rel_df.corr()

# %%
corrs[["FPTS_TG"]].tail(15)
# Out:
#                            FPTS_TG
# REC_RECEIVING/G_avg_FP    0.664052
# TGT_RECEIVING/G_avg_FP    0.656676
# YDS_RECEIVING/G_avg_FP    0.675593
# TD_RECEIVING/G_avg_FP     0.620643
# YDS/REC_RECEIVING_avg_FP  0.641492
# YDS/TGT_RECEIVING_avg_FP  0.673086
# REC/TGT_RECEIVING_avg_FP  0.681433
# REC_RECEIVING/G_ewm_FP    0.678375
# TGT_RECEIVING/G_ewm_FP    0.673946
# YDS_RECEIVING/G_ewm_FP    0.690727
# TD_RECEIVING/G_ewm_FP     0.629631
# YDS/REC_RECEIVING_ewm_FP  0.656454
# YDS/TGT_RECEIVING_ewm_FP  0.684831
# REC/TGT_RECEIVING_ewm_FP  0.692830
# Career_Years_FP           0.692830

# %%
#model_cols = ["Season"]
for i, vals in corrs[["FPTS_TG"]].tail(15).iterrows():
    val = vals["FPTS_TG"]
    if val > 0.65 or val < -0.65:
        model_cols.append(i)

# %%
model_cols
# Out:
# ['Season',
#  'AVG',
#  'FPTS_TG',
#  'FPTS/G_MISC_avg',
#  'REC_RECEIVING/G_avg',
#  'TGT_RECEIVING/G_avg',
#  'YDS_RECEIVING/G_avg',
#  'TD_RECEIVING/G_avg',
#  'FPTS/G_MISC_ewm',
#  'REC_RECEIVING/G_ewm',
#  'TGT_RECEIVING/G_ewm',
#  'YDS_RECEIVING/G_ewm',
#  'TD_RECEIVING/G_ewm',
#  'YDS/REC_RECEIVING_avg_ADP',
#  'YDS/TGT_RECEIVING_avg_ADP',
#  'REC/TGT_RECEIVING_avg_ADP',
#  'YDS/REC_RECEIVING_ewm_ADP',
#  'YDS/TGT_RECEIVING_ewm_ADP',
#  'REC/TGT_RECEIVING_ewm_ADP',
#  'REC_RECEIVING/G_avg_FP',
#  'TGT_RECEIVING/G_avg_FP',
#  'YDS_RECEIVING/G_avg_FP',
#  'YDS/TGT_RECEIVING_avg_FP',
#  'REC/TGT_RECEIVING_avg_FP',
#  'REC_RECEIVING/G_ewm_FP',
#  'TGT_RECEIVING/G_ewm_FP',
#  'YDS_RECEIVING/G_ewm_FP',
#  'YDS/REC_RECEIVING_ewm_FP',
#  'YDS/TGT_RECEIVING_ewm_FP',
#  'REC/TGT_RECEIVING_ewm_FP',
#  'Career_Years_FP']

# %%
import pickle
with open("model features/wr_feats", "wb") as fp:   #Pickling
    pickle.dump(model_cols, fp)

# %%
model_df = rel_df[model_cols].dropna()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %%
X = model_df.drop(["FPTS_TG", "Season"], axis=1)
y = model_df[["FPTS_TG"]]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

lr = LinearRegression()
sc = preprocessing.StandardScaler()

X_train_sc = sc.fit_transform(X_train)

X_test_sc = sc.transform(X_test)

lr.fit(X_train_sc, y_train)
y_pred = lr.predict(X_test_sc)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
def evaluate(y_test, y_pred):
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    print("mae: ", mae)
    print("mse: ", mse)
    print("r2: ", r2)

# %%
evaluate(y_test, y_pred)
# Out:
# mae:  2.3710211361310054
# mse:  9.070542136781366
# r2:  0.5832776929890328

# %%
X_22 = model_df[model_df.Season == 2022].drop(["FPTS_TG", "Season"], axis=1)
mdd = df[df.Season == 2022][["FPTS_TG", "Player"]].copy()
mdd["comp"] = lr.predict(sc.transform(X_22))

evaluate(mdd.FPTS_TG, mdd.comp)
# Out:
# mae:  1.7771186788344422
# mse:  4.751222693924019
# r2:  0.668414754767513

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
random_grid = {'n_estimators': [200, 400, 600],
               'max_features': ["sqrt"],
               'max_depth': [2, 5, 10, 20],
               'min_samples_split': [2, 5, 10],
              }

# %%
rf = RandomForestRegressor()

# %%
rf_random = RandomizedSearchCV(estimator = rf,param_distributions = random_grid,n_iter = 100, cv = 5, verbose=99, random_state=21, n_jobs = -1)

# %%
rf_random.fit(X_train, y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:305: UserWarning: The total space of parameters 36 is smaller than n_iter=100. Running 36 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:909: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'max_depth': [2, 5, 10, 20],
#                                         'max_features': ['sqrt'],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [200, 400, 600]},
#                    random_state=21, verbose=99)

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 400,
#  'min_samples_split': 10,
#  'max_features': 'sqrt',
#  'max_depth': 5}

# %%
rf_opt = RandomForestRegressor(max_depth=5, max_features="sqrt", min_samples_split = 10, n_estimators=400, random_state=0)

# %%
rf_opt.fit(X_train, y_train)
# Out:
# C:\Users\sergi\AppData\Local\Temp\ipykernel_29460\2599501171.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_opt.fit(X_train, y_train)
# RandomForestRegressor(max_depth=5, max_features='sqrt', min_samples_split=10,
#                       n_estimators=400, random_state=0)

# %%
y_pred = rf_opt.predict(X_test)

# %%
evaluate(y_train, rf_opt.predict(X_train))
# Out:
# mae:  1.7933622138081615
# mse:  5.2755793046988595
# r2:  0.7361131103582583

# %%
evaluate(y_test, y_pred)
# Out:
# mae:  2.2509980098467186
# mse:  7.724966484526112
# r2:  0.6450966429051366

# %%
X_22 = model_df[model_df.Season == 2022].drop(["FPTS_TG", "Season"], axis=1)
mdd = df[df.Season == 2022][["FPTS_TG", "Player"]].copy()
mdd["comp"] = rf_opt.predict((X_22))

evaluate(mdd.FPTS_TG, mdd.comp)
# Out:
# mae:  1.640871643988367
# mse:  3.8731542206755836
# r2:  0.7296946754930419

# %%
mdd.head(30)
# Out:
#      FPTS_TG                     Player       comp
# 560     17.9     Justin Jefferson (MIN)  15.809891
# 561     16.8         Davante Adams (LV)  16.371283
# 562     16.6          Tyreek Hill (MIA)  13.564888
# 563     15.7         Stefon Diggs (BUF)  14.592796
# 564     15.0           A.J. Brown (PHI)  12.023590
# 565     14.6          CeeDee Lamb (DAL)  12.513669
# 566     13.0        Jaylen Waddle (MIA)  11.790145
# 567     13.4    Amon-Ra St. Brown (DET)  11.587464
# 568     12.2         Amari Cooper (CLE)  11.286075
# 569     12.2        DeVonta Smith (PHI)   9.246143
# 570     11.8       Christian Kirk (JAC)   8.049859
# 571     15.3        Ja'Marr Chase (CIN)  16.054622
# 572     12.2        Tyler Lockett (SEA)  10.026799
# 573     11.2       Terry McLaurin (WAS)  11.449671
# 574     11.1         Brandon Aiyuk (SF)  10.563350
# 575     12.5            Mike Evans (TB)  12.442085
# 576     12.4          Tee Higgins (CIN)  12.033532
# 577     10.7           DK Metcalf (SEA)  11.677167
# 579     11.4          Chris Godwin (TB)  10.992556
# 580     11.4          Jerry Jeudy (DEN)   9.919216
# 581      9.9             DJ Moore (CHI)  11.189634
# 582     10.4  Michael Pittman Jr. (IND)  12.193885
# 583     18.2          Cooper Kupp (LAR)  15.915642
# 585      9.8            Zay Jones (JAC)   6.700515
# 586      9.8           Gabe Davis (BUF)   8.822752
# 587     10.5         Jakobi Meyers (LV)   6.814339
# 588      9.1   JuJu Smith-Schuster (NE)   9.369471
# 589      8.6           Tyler Boyd (CIN)   7.018424
# 590      8.5         Adam Thielen (CAR)  11.942738
# 591     11.2        Mike Williams (LAC)  11.558930
