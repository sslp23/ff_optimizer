# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
df = pd.read_csv(f"rb_proc_data.csv")

# %%
df = df[df["Rookie"] == 0]

# %%
df
# Out:
#        pid                    Player  Season    AVG  FPTS_TG  FPTS/G_MISC_avg  \
# 0    13912       Todd Gurley II (FA)    2018    1.0     24.5        16.533333
# 2    16393  Christian McCaffrey (SF)    2018   15.0     20.8        11.800000
# 3    16421         Alvin Kamara (NO)    2018    6.5     20.9        17.100000
# 4    15498      Ezekiel Elliott (FA)    2018    3.5     19.4        19.800000
# 5    16447        James Conner (ARI)    2018  189.5     19.4         1.000000
# ..     ...                       ...     ...    ...      ...              ...
# 505  17309          Sony Michel (FA)    2022  195.5      2.0         8.900000
# 506  17514      Darrel Williams (FA)    2022  203.5      3.8         5.075000
# 507  17243     Ronald Jones II (DAL)    2022  164.0      3.1         7.125000
# 511  13943           Mike Davis (FA)    2022  189.5      0.6         6.825000
# 512  18820         John Lovett (MIA)    2022  275.0      0.0         0.000000
#
#      ATT_RUSHING/G_avg  YDS_RUSHING/G_avg  TD_RUSHING/G_avg  \
# 0            17.863462          75.796474          0.670299
# 2             7.312500          27.187500          0.125000
# 3             7.500000          45.500000          0.500000
# 4            22.833333         103.516667          0.850000
# 5             2.285714          10.285714          0.000000
# ..                 ...                ...               ...
# 505          13.131874          57.052539          0.311361
# 506           4.122855          15.617341          0.166360
# 507           8.438294          37.132341          0.313194
# 511           6.916912          27.226225          0.210784
# 512           0.375000           0.750000          0.000000
#
#      REC_RECEIVING/G_avg  ...  TD_RECEIVING/G_ls  FL_MISC/G_ls  \
# 0               2.856517  ...           0.400000      0.133333
# 2               5.000000  ...           0.312500      0.062500
# 3               5.062500  ...           0.312500      0.062500
# 4               2.366667  ...           0.200000      0.100000
# 5               0.000000  ...           0.000000      0.000000
# ..                   ...  ...                ...           ...
# 505             0.825383  ...           0.058824      0.058824
# 506             1.409926  ...           0.117647      0.000000
# 507             1.345486  ...           0.000000      0.133333
# 511             2.342892  ...           0.058824      0.176471
# 512             0.000000  ...                NaN           NaN
#
#      YDS/ATT_RUSHING_ls  TD/ATT_RUSHING_ls  YDS/REC_RECEIVING_ls  \
# 0              4.677419           0.046595             12.312500
# 2              3.717949           0.017094              8.137500
# 3              6.066667           0.066667             10.197531
# 4              4.061983           0.028926             10.346154
# 5              4.500000           0.000000                   NaN
# ..                  ...                ...                   ...
# 505            4.062500           0.019231              6.095238
# 506            3.875000           0.041667              9.617021
# 507            4.237624           0.039604              6.400000
# 511            3.644928           0.021739              5.886364
# 512                 NaN                NaN                   NaN
#
#      YDS/TGT_RECEIVING_ls  REC/TGT_RECEIVING_ls  TD/TGT_RECEIVING_ls  Rookie  \
# 0                9.057471              0.735632             0.068966       0
# 2                5.761062              0.707965             0.044248       0
# 3                8.260000              0.810000             0.050000       0
# 4                7.078947              0.684211             0.052632       0
# 5                0.000000              0.000000             0.000000       0
# ..                    ...                   ...                  ...     ...
# 505              3.878788              0.636364             0.030303       0
# 506              7.929825              0.824561             0.035088       0
# 507              4.923077              0.769231             0.000000       0
# 511              4.465517              0.758621             0.017241       0
# 512                   NaN                   NaN                  NaN       0
#
#      Career_Years
# 0               3
# 2               1
# 3               1
# 4               2
# 5               1
# ..            ...
# 505             4
# 506             4
# 507             4
# 511             7
# 512             1
#
# [421 rows x 52 columns]

# %%
df.Season.value_counts()
# Out:
# 2018    96
# 2021    95
# 2019    86
# 2020    84
# 2022    60
# Name: Season, dtype: int64

# %%
corrs = df.corr()

# %%
rel_cols = ["Season"]
for i, vals in corrs[["FPTS_TG"]].iterrows():
    val = vals["FPTS_TG"]
    if (val > 0.4 or val < -0.4) and "_ls" not in i:
        rel_cols.append(i)

# %%
rel_df = df[rel_cols]

# %%
for col in rel_cols[2:]:
    new_c = rel_df[col]/rel_df["AVG"]
    
    new_name = col+"_ADP"
    
    rel_df[new_name] = new_c
# Out:
# /home/sergio/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
corrs = rel_df.corr()

# %%
corrs[["FPTS_TG"]]
# Out:
#                           FPTS_TG
# Season                   0.091030
# AVG                     -0.723013
# FPTS_TG                  1.000000
# FPTS/G_MISC_avg          0.632428
# ATT_RUSHING/G_avg        0.515702
# YDS_RUSHING/G_avg        0.554760
# TD_RUSHING/G_avg         0.550033
# REC_RECEIVING/G_avg      0.466246
# TGT_RECEIVING/G_avg      0.459082
# YDS_RECEIVING/G_avg      0.481864
# FPTS/G_MISC_ewm          0.660747
# ATT_RUSHING/G_ewm        0.543053
# YDS_RUSHING/G_ewm        0.581225
# TD_RUSHING/G_ewm         0.565755
# REC_RECEIVING/G_ewm      0.487297
# TGT_RECEIVING/G_ewm      0.479730
# YDS_RECEIVING/G_ewm      0.499358
# TD_RECEIVING/G_ewm       0.408428
# FPTS_TG_ADP              0.491184
# FPTS/G_MISC_avg_ADP      0.427226
# ATT_RUSHING/G_avg_ADP    0.440515
# YDS_RUSHING/G_avg_ADP    0.430274
# TD_RUSHING/G_avg_ADP     0.404449
# REC_RECEIVING/G_avg_ADP  0.402150
# TGT_RECEIVING/G_avg_ADP  0.404084
# YDS_RECEIVING/G_avg_ADP  0.410353
# FPTS/G_MISC_ewm_ADP      0.426897
# ATT_RUSHING/G_ewm_ADP    0.441968
# YDS_RUSHING/G_ewm_ADP    0.432278
# TD_RUSHING/G_ewm_ADP     0.397617
# REC_RECEIVING/G_ewm_ADP  0.406797
# TGT_RECEIVING/G_ewm_ADP  0.409597
# YDS_RECEIVING/G_ewm_ADP  0.412887
# TD_RECEIVING/G_ewm_ADP   0.402789

# %%
rel_df = df[rel_cols]

# %%
for col in rel_df.columns[2:]:
    if "FPTS" not in col:
        if "_avg" in col:
            new_c = rel_df["FPTS/G_MISC_avg"]*rel_df[col]
        elif "_ewm" in col:
            new_c = rel_df["FPTS/G_MISC_ewm"]*rel_df[col]
        
        new_name = col+"_FP"

        rel_df[new_name] = new_c
# Out:
# /home/sergio/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %%
corrs = rel_df.corr()

# %%
corrs[["FPTS_TG"]]#.tail(30)
# Out:
#                          FPTS_TG
# Season                  0.091030
# AVG                    -0.723013
# FPTS_TG                 1.000000
# FPTS/G_MISC_avg         0.632428
# ATT_RUSHING/G_avg       0.515702
# YDS_RUSHING/G_avg       0.554760
# TD_RUSHING/G_avg        0.550033
# REC_RECEIVING/G_avg     0.466246
# TGT_RECEIVING/G_avg     0.459082
# YDS_RECEIVING/G_avg     0.481864
# FPTS/G_MISC_ewm         0.660747
# ATT_RUSHING/G_ewm       0.543053
# YDS_RUSHING/G_ewm       0.581225
# TD_RUSHING/G_ewm        0.565755
# REC_RECEIVING/G_ewm     0.487297
# TGT_RECEIVING/G_ewm     0.479730
# YDS_RECEIVING/G_ewm     0.499358
# TD_RECEIVING/G_ewm      0.408428
# FPTS_TG_FP              0.402789
# FPTS/G_MISC_avg_FP      0.402789
# ATT_RUSHING/G_avg_FP    0.582897
# YDS_RUSHING/G_avg_FP    0.598147
# TD_RUSHING/G_avg_FP     0.588284
# REC_RECEIVING/G_avg_FP  0.565953
# TGT_RECEIVING/G_avg_FP  0.565454
# YDS_RECEIVING/G_avg_FP  0.572686
# FPTS/G_MISC_ewm_FP      0.572686
# ATT_RUSHING/G_ewm_FP    0.614615
# YDS_RUSHING/G_ewm_FP    0.628326
# TD_RUSHING/G_ewm_FP     0.605054
# REC_RECEIVING/G_ewm_FP  0.593797
# TGT_RECEIVING/G_ewm_FP  0.593824
# YDS_RECEIVING/G_ewm_FP  0.597310
# TD_RECEIVING/G_ewm_FP   0.521072

# %%
model_cols = ["Season"]
for i, vals in corrs[["FPTS_TG"]].iterrows():
    val = vals["FPTS_TG"]
    if val > 0.55 or val < -0.55:
        model_cols.append(i)

# %%
import pickle
with open("rb_feats", "wb") as fp:   #Pickling
    pickle.dump(model_cols, fp)

# %%
model_cols
# Out:
# ['Season',
#  'AVG',
#  'FPTS_TG',
#  'FPTS/G_MISC_avg',
#  'YDS_RUSHING/G_avg',
#  'TD_RUSHING/G_avg',
#  'FPTS/G_MISC_ewm',
#  'YDS_RUSHING/G_ewm',
#  'TD_RUSHING/G_ewm',
#  'ATT_RUSHING/G_avg_FP',
#  'YDS_RUSHING/G_avg_FP',
#  'TD_RUSHING/G_avg_FP',
#  'REC_RECEIVING/G_avg_FP',
#  'TGT_RECEIVING/G_avg_FP',
#  'YDS_RECEIVING/G_avg_FP',
#  'FPTS/G_MISC_ewm_FP',
#  'ATT_RUSHING/G_ewm_FP',
#  'YDS_RUSHING/G_ewm_FP',
#  'TD_RUSHING/G_ewm_FP',
#  'REC_RECEIVING/G_ewm_FP',
#  'TGT_RECEIVING/G_ewm_FP',
#  'YDS_RECEIVING/G_ewm_FP']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
model_df = rel_df[model_cols]

# %%
model_df.columns
# Out:
# Index(['Season', 'AVG', 'FPTS_TG', 'FPTS/G_MISC_avg', 'YDS_RUSHING/G_avg',
#        'TD_RUSHING/G_avg', 'FPTS/G_MISC_ewm', 'YDS_RUSHING/G_ewm',
#        'TD_RUSHING/G_ewm', 'ATT_RUSHING/G_avg_FP', 'YDS_RUSHING/G_avg_FP',
#        'TD_RUSHING/G_avg_FP', 'REC_RECEIVING/G_avg_FP',
#        'TGT_RECEIVING/G_avg_FP', 'YDS_RECEIVING/G_avg_FP',
#        'FPTS/G_MISC_ewm_FP', 'ATT_RUSHING/G_ewm_FP', 'YDS_RUSHING/G_ewm_FP',
#        'TD_RUSHING/G_ewm_FP', 'REC_RECEIVING/G_ewm_FP',
#        'TGT_RECEIVING/G_ewm_FP', 'YDS_RECEIVING/G_ewm_FP'],
#       dtype='object')

# %%
plt.figure(figsize=(15, 10))
sns.regplot(model_df["AVG"], model_df["FPTS_TG"])
# Out:
# /home/sergio/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='AVG', ylabel='FPTS_TG'>

# %%
#plt.figure(figsize=(15, 10))
#sns.regplot(model_df["FPTS_TG"], model_df["REC_RECEIVING_avg_FP"])

# %%
plt.figure(figsize=(15, 10))
#sns.regplot(model_df["FPTS_TG"], model_df["REC_RECEIVING/G_ls_FP"])

# %%
model_df = model_df.fillna(0)

# %%
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %%
X = model_df.drop(["FPTS_TG", "Season"], axis=1)
y = model_df[["FPTS_TG"]]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

lr = LinearRegression()

# %%
sc = preprocessing.StandardScaler()

# %%
X_train_sc = sc.fit_transform(X_train)

# %%
X_test_sc = sc.transform(X_test)

# %%
lr.fit(X_train_sc, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test_sc)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 2.8822021849969754

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 14.023247746183577

# %%
r2_score(y_test, y_pred)
# Out:
# 0.5824382903079977

# %%
y_test
# Out:
#      FPTS_TG
# 149      9.0
# 415      3.7
# 24      10.6
# 117     25.8
# 157      8.0
# ..       ...
# 379      5.4
# 92       0.5
# 78       3.0
# 65       4.5
# 100      0.7
#
# [106 rows x 1 columns]

# %%
y_pred
# Out:
# array([[ 6.28992987],
#        [ 2.41927015],
#        [ 6.85455346],
#        [16.16120553],
#        [ 7.43085445],
#        [ 2.72808892],
#        [ 8.16826706],
#        [ 2.41267045],
#        [12.10275788],
#        [ 5.85582702],
#        [ 0.30972418],
#        [ 6.89869126],
#        [11.86067476],
#        [20.24706836],
#        [ 7.30171638],
#        [15.18060871],
#        [ 2.43197167],
#        [ 6.67743986],
#        [ 5.81472485],
#        [ 3.68093507],
#        [ 9.27173872],
#        [ 9.32680385],
#        [12.23047882],
#        [ 4.05869639],
#        [17.76315731],
#        [11.99522424],
#        [ 7.75449764],
#        [ 6.5670911 ],
#        [ 8.37912115],
#        [12.60659173],
#        [ 4.85520366],
#        [ 3.24793824],
#        [11.92865629],
#        [10.73182838],
#        [ 9.61549991],
#        [ 8.88576684],
#        [10.18784504],
#        [ 6.04404138],
#        [ 9.77743196],
#        [ 5.62222377],
#        [ 5.43691853],
#        [ 6.31929216],
#        [ 6.60137813],
#        [10.84675854],
#        [ 7.03174569],
#        [11.35276522],
#        [ 0.39201581],
#        [13.05489588],
#        [ 2.61067629],
#        [ 5.24355527],
#        [ 7.27471108],
#        [ 5.95689803],
#        [ 7.89768947],
#        [ 3.21772513],
#        [ 8.05005413],
#        [ 5.22019608],
#        [ 8.15730913],
#        [10.20341432],
#        [ 6.35800541],
#        [11.50812363],
#        [ 1.9453242 ],
#        [ 0.69626468],
#        [ 8.86023948],
#        [ 9.36825784],
#        [12.69829622],
#        [ 6.75586985],
#        [ 6.18499801],
#        [ 4.6165589 ],
#        [ 2.51991462],
#        [ 3.99680978],
#        [ 9.14006229],
#        [ 1.44529021],
#        [ 7.63048862],
#        [ 8.61449472],
#        [10.32722157],
#        [ 5.79457111],
#        [11.31859159],
#        [ 5.98250247],
#        [ 8.77348072],
#        [ 6.15082195],
#        [ 8.64022452],
#        [ 3.37162375],
#        [ 6.42497472],
#        [11.43711804],
#        [11.84817449],
#        [16.6880051 ],
#        [14.17128994],
#        [ 0.51427604],
#        [11.00893988],
#        [ 4.99624054],
#        [ 5.8078155 ],
#        [ 3.68032262],
#        [ 8.34842179],
#        [ 6.7409209 ],
#        [ 8.43661748],
#        [11.98237266],
#        [ 6.56293259],
#        [ 8.14370239],
#        [ 5.84870778],
#        [10.09263314],
#        [ 8.28969116],
#        [ 5.41104323],
#        [ 0.35615107],
#        [ 1.58926982],
#        [ 7.77099431],
#        [ 4.74065226]])

# %%
X_22 = model_df[model_df.Season == 2022].drop(["FPTS_TG", "Season"], axis=1)

# %%
#df[df.Season == 2022]

# %%
mdd = df[df.Season == 2022][["FPTS_TG", "Player"]].copy()

# %%
mdd["comp"] = lr.predict(sc.transform(X_22))

# %%
mdd
# Out:
#      FPTS_TG                       Player       comp
# 440     18.8          Austin Ekeler (LAC)  14.567534
# 441     18.5     Christian McCaffrey (SF)  17.763157
# 442     17.8             Josh Jacobs (LV)  10.846759
# 443     17.9          Derrick Henry (TEN)  18.777485
# 444     15.8             Nick Chubb (CLE)  14.706717
# 445     16.0         Saquon Barkley (NYG)   8.453664
# 446     14.3           Tony Pollard (DAL)   9.497816
# 447     12.9         Jamaal Williams (NO)   6.948762
# 448     12.9             Aaron Jones (GB)  14.171290
# 449     12.8             Dalvin Cook (FA)  14.797285
# 450     12.6     Rhamondre Stevenson (NE)   9.228996
# 451     14.0              Joe Mixon (CIN)  11.542249
# 452     12.2          Miles Sanders (CAR)   9.521660
# 453     11.9           Najee Harris (PIT)  10.698376
# 454     11.9       Leonard Fournette (FA)  11.710606
# 457     12.2            Alvin Kamara (NO)  13.432263
# 458     11.8         Ezekiel Elliott (FA)   8.110883
# 459     13.6           James Conner (ARI)  11.437118
# 460      9.9         Jerick McKinnon (KC)   5.222176
# 461     11.9          D'Andre Swift (PHI)  11.995224
# 462     10.0       David Montgomery (DET)  11.318592
# 463      9.4       Devin Singletary (HOU)   8.742337
# 464      9.0               AJ Dillon (GB)  10.044884
# 465      9.6         Raheem Mostert (MIA)   7.411367
# 468      9.2        Jeff Wilson Jr. (MIA)   5.622224
# 469     11.1  Cordarrelle Patterson (ATL)   8.224839
# 470      9.5         Antonio Gibson (WAS)  10.671498
# 471      9.0              Cam Akers (LAR)   9.766807
# 472     11.0        Jonathan Taylor (IND)  17.567148
# 473      8.0         D'Onta Foreman (CHI)   6.792354
# 475      7.7          Samaje Perine (DEN)   4.855204
# 477      8.7         Khalil Herbert (CHI)   6.554152
# 478      6.4             Kareem Hunt (FA)  10.561691
# 481      6.6         Michael Carter (NYJ)   8.243769
# 483      8.0            Kenyan Drake (FA)   5.680550
# 484      9.0   Clyde Edwards-Helaire (KC)   9.629430
# 485      7.6         James Robinson (NYG)   7.991445
# 486      7.5          Damien Harris (BUF)   9.736622
# 487      4.8     Alexander Mattison (MIN)   7.879904
# 488      5.8          Chuba Hubbard (CAR)   5.723157
# 489      9.7           J.K. Dobbins (BAL)   9.295206
# 490      5.9            Eno Benjamin (NO)   5.487097
# 491      4.5       Kenneth Gainwell (PHI)   6.358005
# 492      7.5      Melvin Gordon III (BAL)   9.085174
# 493      5.6       Dontrell Hilliard (FA)   4.603502
# 494      4.2           Nyheim Hines (BUF)   7.271849
# 495      5.1           Chase Edmonds (TB)   9.958116
# 496      6.5   Darrell Henderson Jr. (FA)   8.343569
# 497      6.6            Gus Edwards (BAL)   6.150822
# 498     10.0          Rashaad Penny (PHI)   9.140062
# 499      4.7           J.D. McKissic (FA)   6.931336
# 500      4.2          Mark Ingram II (FA)   6.755555
# 501      8.4         Elijah Mitchell (SF)  11.732109
# 502      4.3             Marlon Mack (FA)   6.677440
# 503      8.5       Javonte Williams (DEN)  10.874972
# 505      2.0             Sony Michel (FA)   6.672979
# 506      3.8         Darrel Williams (FA)   5.740883
# 507      3.1        Ronald Jones II (DAL)   6.812468
# 511      0.6              Mike Davis (FA)   5.929566
# 512      0.0            John Lovett (MIA)   3.996810

# %%
#from sklearn.tree import RandomForestRegressor

# %%
svm = SVR(kernel='rbf')
svm.fit(X_train_sc,y_train)
# Out:
# SVR()

# %%
y_pred = svm.predict(X_test_sc)

# %%
X
# Out:
#         AVG  FPTS/G_MISC_avg  FPTS_MISC_avg  FPTS/G_MISC_ewm  FPTS_MISC_ewm  \
# 0       1.0        16.533333     242.033333        17.569687     260.656065
# 2      15.0        11.800000     188.600000        11.800000     188.600000
# 3       6.5        17.100000     273.900000        17.100000     273.900000
# 4       3.5        19.800000     249.800000        19.662742     239.574257
# 5     189.5         1.000000      14.400000         1.000000      14.400000
# ...     ...              ...            ...              ...            ...
# 1237  458.0         2.150000      32.200000         2.415938      36.780996
# 1239  290.0         3.366667      51.033333         3.159912      47.980700
# 1240  433.0         0.400000       5.100000         0.400000       5.100000
# 1241  364.0         0.250000       1.500000         0.207107       1.242641
# 1243  205.0         0.000000       0.000000         0.000000       0.000000
#
#       FPTS/G_MISC_ls  FPTS_MISC_ls  REC_RECEIVING_avg_FP  \
# 0              23.40         351.3          10326.755556
# 2              11.80         188.6          15088.000000
# 3              17.10         273.9          22185.900000
# 4              19.00         190.2           7244.200000
# 5               1.00          14.4              0.000000
# ...              ...           ...                   ...
# 1237            3.70          58.9            724.500000
# 1239            3.60          58.2           1207.788889
# 1240            0.40           5.1             15.300000
# 1241            0.25           1.5              1.500000
# 1243            0.00           0.0              0.000000
#
#       TGT_RECEIVING_avg_FP  YDS_RECEIVING_avg_FP  ...  TGT_RECEIVING/G_ewm_FP  \
# 0             13795.900000         105123.144444  ...             1105.787481
# 2             21311.800000         122778.600000  ...             1331.987500
# 3             27390.000000         226241.400000  ...             1711.875000
# 4              9742.200000          78936.800000  ...              797.915948
# 5                14.400000              0.000000  ...                1.028571
# ...                    ...                   ...  ...                     ...
# 1237            949.900000           6101.900000  ...               81.527282
# 1239           1769.155556          13540.844444  ...              115.915649
# 1240             20.400000            183.600000  ...                1.457143
# 1241             10.500000              4.500000  ...                1.449747
# 1243              0.000000              0.000000  ...                0.000000
#
#       YDS_RECEIVING/G_ewm_FP  REC_RECEIVING_ls_FP  TGT_RECEIVING_ls_FP  \
# 0                8764.752903              22483.2              30563.1
# 2                7673.662500              15088.0              21311.8
# 3               14140.087500              22185.9              27390.0
# 4                6176.613256               4945.2               7227.6
# 5                   0.000000                  0.0                 14.4
# ...                      ...                  ...                  ...
# 1237              520.751905               2356.0               3121.7
# 1239              784.781789               1804.2               2677.2
# 1240               13.114286                 15.3                 20.4
# 1241                0.621320                  1.5                 10.5
# 1243                0.000000                  0.0                  0.0
#
#       YDS_RECEIVING_ls_FP  FPTS/G_MISC_ls_FP  FPTS_MISC_ls_FP  \
# 0                276824.4           276824.4         276824.4
# 2                122778.6           122778.6         122778.6
# 3                226241.4           226241.4         226241.4
# 4                 51163.8            51163.8          51163.8
# 5                     0.0                0.0              0.0
# ...                   ...                ...              ...
# 1237              20556.1            20556.1          20556.1
# 1239              16703.4            16703.4          16703.4
# 1240                183.6              183.6            183.6
# 1241                  4.5                4.5              4.5
# 1243                  0.0                0.0              0.0
#
#       REC_RECEIVING/G_ls_FP  TGT_RECEIVING/G_ls_FP  YDS_RECEIVING/G_ls_FP
# 0               1498.880000            2037.540000           18454.960000
# 2                943.000000            1331.987500            7673.662500
# 3               1386.618750            1711.875000           14140.087500
# 4                494.520000             722.760000            5116.380000
# 5                  0.000000               1.028571               0.000000
# ...                     ...                    ...                    ...
# 1237             147.250000             195.106250            1284.756250
# 1239             112.762500             167.325000            1043.962500
# 1240               1.092857               1.457143              13.114286
# 1241               0.250000               1.750000               0.750000
# 1243               0.000000               0.000000               0.000000
#
# [1046 rows x 31 columns]
